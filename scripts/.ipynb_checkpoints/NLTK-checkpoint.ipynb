# %%
import pandas as pd
import numpy as np
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/rashmi/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
df=pd.read_csv('datasets/flipkart_laptop_review_data.csv')
df
# Out:
#       Product Review ID                  Title  rating  \
# 0                     1            Really Nice     4.0
# 1                     1      Terrific purchase     5.0
# 2                     1         Decent product     3.0
# 3                     1           Nice product     4.0
# 4                     1              Excellent     5.0
# ...                 ...                    ...     ...
# 4890                743     Highly recommended     5.0
# 4891                743           Does the job     3.0
# 4892                743          Great product     5.0
# 4893                743    Best in the market!     5.0
# 4894                743  Mind-blowing purchase     5.0
#
#                                           detail_review  upvote  downvote
# 0     The base is becoming a bit Heat within 30 minu...     289        60
# 1     Hey everyone After reading all reviews I have ...     303        71
# 2     Good for Normal useBattery 7/10Display 6/10Mul...      19         1
# 3                  In this price range its best laptop.     109        22
# 4     Very fast laptop go for it little bit heating ...     136        30
# ...                                                 ...     ...       ...
# 4890  This laptop is awesome everything is good the ...       6         1
# 4891  got it for 61k during bbd. performance is quit...       3         0
# 4892                                         Awesome 😎🙌       3         0
# 4893  Don't expect to much from the gaming laptop ba...      12         7
# 4894  Worth for the price, does the job quite wellTh...       4         1
#
# [4895 rows x 6 columns]

# %%
review_title = pd.DataFrame(data=df['Title'])
review_data = pd.DataFrame(data=df['detail_review'])

# %%
review_data.head(10)
# Out:
#                                        detail_review
# 0  The base is becoming a bit Heat within 30 minu...
# 1  Hey everyone After reading all reviews I have ...
# 2  Good for Normal useBattery 7/10Display 6/10Mul...
# 3               In this price range its best laptop.
# 4  Very fast laptop go for it little bit heating ...
# 5  Nice product suitable for any type of working ...
# 6                                        Nice laptop
# 7  This Is one of the best laptop..good battery b...
# 8  Received today don't know about performance bu...
# 9                                    Value For Money

# %%
review_title.head(10)
# Out:
#                    Title
# 0            Really Nice
# 1      Terrific purchase
# 2         Decent product
# 3           Nice product
# 4              Excellent
# 5              Excellent
# 6  Mind-blowing purchase
# 7          Great product
# 8           Nice product
# 9           Nice product

# %%
blanks = []
# .itertuples() generates an iterator object of the DataFrame, 
#  returning each row as a Python Tuple object.
# The isspace() method returns True if all the characters in a string are 
# whitespaces, otherwise False.
for i, rv in review_data.itertuples():
    if type(rv)==str:
        if rv.isspace():
            blanks.append(i)
t_blanks = []
        
for j, rt in review_title.itertuples():
    if type(rt)==str:
        if rt.isspace():
            t_blanks.append(j)

# %%
blanks
# Out:
# []

# %%
t_blanks
# Out:
# []

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sid = SentimentIntensityAnalyzer()

# %%
review_data['detail_review'] = review_data['detail_review'].apply(lambda review: str(review))


review_title['Title'] = review_title['Title'].apply(lambda review_t: str(review_t))

# %%
review_data['score'] = review_data['detail_review'].apply(lambda review: sid.polarity_scores(review))


review_title['t_score'] = review_title['Title'].apply(lambda t_review: sid.polarity_scores(t_review))

# %%
review_data.head(10)
# Out:
#                                        detail_review  \
# 0  The base is becoming a bit Heat within 30 minu...
# 1  Hey everyone After reading all reviews I have ...
# 2  Good for Normal useBattery 7/10Display 6/10Mul...
# 3               In this price range its best laptop.
# 4  Very fast laptop go for it little bit heating ...
# 5  Nice product suitable for any type of working ...
# 6                                        Nice laptop
# 7  This Is one of the best laptop..good battery b...
# 8  Received today don't know about performance bu...
# 9                                    Value For Money
#
#                                                score
# 0  {'neg': 0.244, 'neu': 0.614, 'pos': 0.142, 'co...
# 1  {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'comp...
# 2  {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'comp...
# 3  {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'comp...
# 4  {'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'comp...
# 5  {'neg': 0.0, 'neu': 0.823, 'pos': 0.177, 'comp...
# 6  {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'comp...
# 7  {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'comp...
# 8  {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'comp...
# 9  {'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'comp...

# %%
review_title.head(10)
# Out:
#                    Title                                            t_score
# 0            Really Nice  {'neg': 0.0, 'neu': 0.244, 'pos': 0.756, 'comp...
# 1      Terrific purchase  {'neg': 0.0, 'neu': 0.244, 'pos': 0.756, 'comp...
# 2         Decent product  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3           Nice product  {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'comp...
# 4              Excellent  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 5              Excellent  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 6  Mind-blowing purchase  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7          Great product  {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...
# 8           Nice product  {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'comp...
# 9           Nice product  {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'comp...

# %%
review_data['compound'] = review_data['score'].apply(lambda dic: dic['compound'])

review_title['t_compound'] = review_title['t_score'].apply(lambda dic: dic['compound'])

# %%
review_data.head()
# Out:
#                                        detail_review  \
# 0  The base is becoming a bit Heat within 30 minu...
# 1  Hey everyone After reading all reviews I have ...
# 2  Good for Normal useBattery 7/10Display 6/10Mul...
# 3               In this price range its best laptop.
# 4  Very fast laptop go for it little bit heating ...
#
#                                                score  compound
# 0  {'neg': 0.244, 'neu': 0.614, 'pos': 0.142, 'co...   -0.3919
# 1  {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'comp...    0.8777
# 2  {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'comp...    0.6757
# 3  {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'comp...    0.6369
# 4  {'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'comp...    0.4782

# %%
review_title.head()
# Out:
#                Title                                            t_score  \
# 0        Really Nice  {'neg': 0.0, 'neu': 0.244, 'pos': 0.756, 'comp...
# 1  Terrific purchase  {'neg': 0.0, 'neu': 0.244, 'pos': 0.756, 'comp...
# 2     Decent product  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3       Nice product  {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'comp...
# 4          Excellent  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
#
#    t_compound
# 0      0.4754
# 1      0.4767
# 2      0.0000
# 3      0.4215
# 4      0.5719

# %%
review_data['sentiment'] = review_data['compound'].apply(lambda com: 'Positive' if com>0  else 'Negative' if com<0  else 'Neutral' )

# %%
review_data.head(10)
# Out:
#                                        detail_review  \
# 0  The base is becoming a bit Heat within 30 minu...
# 1  Hey everyone After reading all reviews I have ...
# 2  Good for Normal useBattery 7/10Display 6/10Mul...
# 3               In this price range its best laptop.
# 4  Very fast laptop go for it little bit heating ...
# 5  Nice product suitable for any type of working ...
# 6                                        Nice laptop
# 7  This Is one of the best laptop..good battery b...
# 8  Received today don't know about performance bu...
# 9                                    Value For Money
#
#                                                score  compound sentiment
# 0  {'neg': 0.244, 'neu': 0.614, 'pos': 0.142, 'co...   -0.3919  Negative
# 1  {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'comp...    0.8777  Positive
# 2  {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'comp...    0.6757  Positive
# 3  {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'comp...    0.6369  Positive
# 4  {'neg': 0.0, 'neu': 0.865, 'pos': 0.135, 'comp...    0.4782  Positive
# 5  {'neg': 0.0, 'neu': 0.823, 'pos': 0.177, 'comp...    0.4215  Positive
# 6  {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'comp...    0.4215  Positive
# 7  {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'comp...    0.8625  Positive
# 8  {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'comp...    0.5719  Positive
# 9  {'neg': 0.0, 'neu': 0.455, 'pos': 0.545, 'comp...    0.3400  Positive

# %%
review_title['t_sentiment'] = review_title['t_compound'].apply(lambda com: 'Positive' if com>0  else 'Negative' if com<0  else 'Neutral' )

# %%
review_title.head(10)
# Out:
#                    Title                                            t_score  \
# 0            Really Nice  {'neg': 0.0, 'neu': 0.244, 'pos': 0.756, 'comp...
# 1      Terrific purchase  {'neg': 0.0, 'neu': 0.244, 'pos': 0.756, 'comp...
# 2         Decent product  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3           Nice product  {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'comp...
# 4              Excellent  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 5              Excellent  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...
# 6  Mind-blowing purchase  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 7          Great product  {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...
# 8           Nice product  {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'comp...
# 9           Nice product  {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'comp...
#
#    t_compound t_sentiment
# 0      0.4754    Positive
# 1      0.4767    Positive
# 2      0.0000     Neutral
# 3      0.4215    Positive
# 4      0.5719    Positive
# 5      0.5719    Positive
# 6      0.0000     Neutral
# 7      0.6249    Positive
# 8      0.4215    Positive
# 9      0.4215    Positive

# %%
import random

# %%
review_data.sample(5)
# Out:
#                                           detail_review  \
# 3748                                        go for it 👍
# 1956  Wanted a laptop with slim looks yet can game s...
# 4114    Sound quality is even worse than phone speaker.
# 91    Playing all nee AAA titles games in 60 fps in ...
# 168   It's a good laptop for decent gaming. Finally ...
#
#                                                   score  compound sentiment
# 3748  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   Neutral
# 1956  {'neg': 0.011, 'neu': 0.931, 'pos': 0.058, 'co...    0.5149  Positive
# 4114  {'neg': 0.307, 'neu': 0.693, 'pos': 0.0, 'comp...   -0.4767  Negative
# 91    {'neg': 0.0, 'neu': 0.732, 'pos': 0.268, 'comp...    0.8126  Positive
# 168   {'neg': 0.0, 'neu': 0.549, 'pos': 0.451, 'comp...    0.8934  Positive

# %%
review_title.sample(10)
# Out:
#                              Title  \
# 4859                     Fabulous!
# 1351                    Delightful
# 2159                     Brilliant
# 3734                 Great product
# 1119                          Good
# 4104                     Brilliant
# 3276                     Wonderful
# 1343                  Nice product
# 3314                        Super!
# 3269  Best touch laptop under 60K.
#
#                                                 t_score  t_compound  \
# 4859  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...      0.5707
# 1351  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...      0.5859
# 2159  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...      0.5859
# 3734  {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...      0.6249
# 1119  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...      0.4404
# 4104  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...      0.5859
# 3276  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...      0.5719
# 1343  {'neg': 0.0, 'neu': 0.263, 'pos': 0.737, 'comp...      0.4215
# 3314  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...      0.6360
# 3269  {'neg': 0.0, 'neu': 0.488, 'pos': 0.512, 'comp...      0.6369
#
#      t_sentiment
# 4859    Positive
# 1351    Positive
# 2159    Positive
# 3734    Positive
# 1119    Positive
# 4104    Positive
# 3276    Positive
# 1343    Positive
# 3314    Positive
# 3269    Positive

# %%
df['combinedSentiment'] = (review_title['t_compound'] + review_data['compound'])/2

# %%
df.head(10)
# Out:
#    Product Review ID                  Title  rating  \
# 0                  1            Really Nice     4.0
# 1                  1      Terrific purchase     5.0
# 2                  1         Decent product     3.0
# 3                  1           Nice product     4.0
# 4                  1              Excellent     5.0
# 5                  1              Excellent     5.0
# 6                  1  Mind-blowing purchase     5.0
# 7                  1          Great product     5.0
# 8                  1           Nice product     4.0
# 9                  1           Nice product     4.0
#
#                                        detail_review  upvote  downvote  \
# 0  The base is becoming a bit Heat within 30 minu...     289        60
# 1  Hey everyone After reading all reviews I have ...     303        71
# 2  Good for Normal useBattery 7/10Display 6/10Mul...      19         1
# 3               In this price range its best laptop.     109        22
# 4  Very fast laptop go for it little bit heating ...     136        30
# 5  Nice product suitable for any type of working ...     134        30
# 6                                        Nice laptop     121        28
# 7  This Is one of the best laptop..good battery b...      25         3
# 8  Received today don't know about performance bu...      96        24
# 9                                    Value For Money      15         1
#
#    combinedSentiment
# 0            0.04175
# 1            0.67720
# 2            0.33785
# 3            0.52920
# 4            0.52505
# 5            0.49670
# 6            0.21075
# 7            0.74370
# 8            0.49670
# 9            0.38075

# %%
df['sentiment'] = df['combinedSentiment'].apply(lambda com: 'Positive' if com>0  else 'Negative' if com<0  else 'Neutral' )

# %%
df
# Out:
#       Product Review ID                  Title  rating  \
# 0                     1            Really Nice     4.0
# 1                     1      Terrific purchase     5.0
# 2                     1         Decent product     3.0
# 3                     1           Nice product     4.0
# 4                     1              Excellent     5.0
# ...                 ...                    ...     ...
# 4890                743     Highly recommended     5.0
# 4891                743           Does the job     3.0
# 4892                743          Great product     5.0
# 4893                743    Best in the market!     5.0
# 4894                743  Mind-blowing purchase     5.0
#
#                                           detail_review  upvote  downvote  \
# 0     The base is becoming a bit Heat within 30 minu...     289        60
# 1     Hey everyone After reading all reviews I have ...     303        71
# 2     Good for Normal useBattery 7/10Display 6/10Mul...      19         1
# 3                  In this price range its best laptop.     109        22
# 4     Very fast laptop go for it little bit heating ...     136        30
# ...                                                 ...     ...       ...
# 4890  This laptop is awesome everything is good the ...       6         1
# 4891  got it for 61k during bbd. performance is quit...       3         0
# 4892                                         Awesome 😎🙌       3         0
# 4893  Don't expect to much from the gaming laptop ba...      12         7
# 4894  Worth for the price, does the job quite wellTh...       4         1
#
#       combinedSentiment sentiment
# 0               0.04175  Positive
# 1               0.67720  Positive
# 2               0.33785  Positive
# 3               0.52920  Positive
# 4               0.52505  Positive
# ...                 ...       ...
# 4890            0.60740  Positive
# 4891            0.35890  Positive
# 4892            0.62490  Positive
# 4893            0.65325  Positive
# 4894            0.26335  Positive
#
# [4895 rows x 8 columns]

# %%
df.sample(10)
# Out:
#       Product Review ID                 Title  rating  \
# 307                  60             Fabulous!     5.0
# 3438                503        Simply awesome     5.0
# 691                 124  Good quality product     4.0
# 1858                260           Really Nice     4.0
# 257                  52   Best in the market!     5.0
# 4282                643             Fabulous!     5.0
# 4851                738             Hated it!     NaN
# 417                  85          Does the job     3.0
# 4091                605             Very Good     4.0
# 4236                632                  Fair     3.0
#
#                                           detail_review  upvote  downvote  \
# 307                                         Nice laptop      10         5
# 3438                   Great product and safe delivery.       4         2
# 691   Best laptop in this price range. I bought it f...      38         5
# 1858  Pro - as given in the features of it.Cons - ba...       0         2
# 257   BEST EVER GAMING LAPTOP WITH AFFORDABLE PRICE....      45         4
# 4282  it's a great deal in this range, superb perfor...      27         6
# 4851  My review after using it 1 month -• After Only...      65        10
# 417   Thanks to flipkart for delivering product. but...       0         2
# 4091  Nice laptop under this price...!Proformance wa...       5         0
# 4236  Pros: Performance is good for decent office wo...     101        57
#
#       combinedSentiment sentiment
# 307             0.49610  Positive
# 3438            0.70775  Positive
# 691             0.64795  Positive
# 1858            0.23770  Positive
# 257             0.69460  Positive
# 4282            0.70940  Positive
# 4851           -0.51540  Negative
# 417            -0.41240  Negative
# 4091            0.65435  Positive
# 4236            0.39045  Positive

# %%
import matplotlib.pyplot as plt

# Assuming 'SentimentCategory' is a categorical column in your DataFrame
sentiment_counts = df['sentiment'].value_counts()
print(sentiment_counts)
# Plotting the bar chart
plt.bar(sentiment_counts.index, sentiment_counts.values, color=['red', 'grey', 'green'])
plt.title('Distribution of Sentiment Categories')
plt.xlabel('Sentiment')
plt.ylabel('Number of Sentiments')
plt.show()
# Out:
# sentiment
# Positive    4217
# Negative     608
# Neutral       70
# Name: count, dtype: int64

# %%
num_rows, num_columns = df.shape
print(f'Total number of rows: {num_rows}')
print(f'Total number of columns: {num_columns}')
# Out:
# Total number of rows: 4895
# Total number of columns: 8

# %%
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

#catagorize the values based on their rating
def categorize_rating(rate):
    if rate == 5:
        return 'Excellent'
    elif rate == 4:
        return 'Good'
    elif rate == 3:
        return 'Average'
    elif rate == 2:
        return 'Poor'
    elif rate == 1:
        return 'Very Poor'
    else:
        return 'Invalid Rating'

df['RatingCategory'] = df['rating'].apply(categorize_rating)

# %%
df.sample(10)
# Out:
#       Product Review ID                                          Title  \
# 4689                708                             Highly recommended
# 2                     1                                 Decent product
# 3013                423                          Mind-blowing purchase
# 2081                293                                    Pretty good
# 4597                691                                       Not good
# 880                 144                                      Wonderful
# 2356                329  Simply awesome and Liked the Keypad very much
# 3873                577                                     Delightful
# 216                  43                                Useless product
# 3954                590                          Mind-blowing purchase
#
#       rating                                      detail_review  upvote  \
# 4689     5.0  The product is great, I just loved it, and ver...      50
# 2        3.0  Good for Normal useBattery 7/10Display 6/10Mul...      19
# 3013     5.0                               Incredible product 👏      15
# 2081     4.0                                               Good       3
# 4597     NaN  If u open two app it ll start to get lagging. ...       7
# 880      5.0                   Keyboard light is most beautiful      40
# 2356     5.0  The product is with great specs at this price ...       6
# 3873     4.0  stylish premium look ● 256gb ssd (NVMe)  , gre...       1
# 216      NaN  i think this laptop has a design issue with fa...       1
# 3954     5.0                                               Good      17
#
#       downvote  combinedSentiment sentiment  RatingCategory
# 4689        15            0.59290  Positive       Excellent
# 2            1            0.33785  Positive         Average
# 3013         2            0.00000   Neutral       Excellent
# 2081         1            0.58365  Positive            Good
# 4597         1           -0.47680  Negative  Invalid Rating
# 880          8            0.60400  Positive       Excellent
# 2356         3            0.87605  Positive       Excellent
# 3873         1            0.70535  Positive            Good
# 216          2           -0.05165  Negative  Invalid Rating
# 3954         1            0.22020  Positive       Excellent

# %%
rating_counts = df['RatingCategory'].value_counts()
print(rating_counts)
# Create a pie chart
plt.figure(figsize=(5, 5))
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Product Ratings')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Display the pie chart
plt.show()
# Out:
# RatingCategory
# Excellent         2954
# Good              1038
# Invalid Rating     608
# Average            295
# Name: count, dtype: int64

# %%
# review_data = review_data.drop('detail_review', axis=1, inplace = True)

# %%
# result = pd.concat(frames,axis=1)
# displa/y(result)

# %%
# result = df.append(review_data)
# display(result)

# %%
df['review_trueness'] =  (df['upvote'])/(df['upvote']+df['downvote'])

# %%
df['review_trueness']
# Out:
# 0       0.828080
# 1       0.810160
# 2       0.950000
# 3       0.832061
# 4       0.819277
#           ...
# 4890    0.857143
# 4891    1.000000
# 4892    1.000000
# 4893    0.631579
# 4894    0.800000
# Name: review_trueness, Length: 4895, dtype: float64

# %%
df
# Out:
#       Product Review ID                  Title  rating  \
# 0                     1            Really Nice     4.0
# 1                     1      Terrific purchase     5.0
# 2                     1         Decent product     3.0
# 3                     1           Nice product     4.0
# 4                     1              Excellent     5.0
# ...                 ...                    ...     ...
# 4890                743     Highly recommended     5.0
# 4891                743           Does the job     3.0
# 4892                743          Great product     5.0
# 4893                743    Best in the market!     5.0
# 4894                743  Mind-blowing purchase     5.0
#
#                                           detail_review  upvote  downvote  \
# 0     The base is becoming a bit Heat within 30 minu...     289        60
# 1     Hey everyone After reading all reviews I have ...     303        71
# 2     Good for Normal useBattery 7/10Display 6/10Mul...      19         1
# 3                  In this price range its best laptop.     109        22
# 4     Very fast laptop go for it little bit heating ...     136        30
# ...                                                 ...     ...       ...
# 4890  This laptop is awesome everything is good the ...       6         1
# 4891  got it for 61k during bbd. performance is quit...       3         0
# 4892                                         Awesome 😎🙌       3         0
# 4893  Don't expect to much from the gaming laptop ba...      12         7
# 4894  Worth for the price, does the job quite wellTh...       4         1
#
#       combinedSentiment sentiment RatingCategory  review_trueness
# 0               0.04175  Positive           Good         0.828080
# 1               0.67720  Positive      Excellent         0.810160
# 2               0.33785  Positive        Average         0.950000
# 3               0.52920  Positive           Good         0.832061
# 4               0.52505  Positive      Excellent         0.819277
# ...                 ...       ...            ...              ...
# 4890            0.60740  Positive      Excellent         0.857143
# 4891            0.35890  Positive        Average         1.000000
# 4892            0.62490  Positive      Excellent         1.000000
# 4893            0.65325  Positive      Excellent         0.631579
# 4894            0.26335  Positive      Excellent         0.800000
#
# [4895 rows x 10 columns]

# %%
# PRS = product recommendation score
def prs_calculation(df):
    if (df['review_trueness'] >= 0.75):
        df['prs'] = df['combinedSentiment']*1
    elif (df['review_trueness'] < 0.75):
        df['prs'] = df['review_trueness']*(df['combinedSentiment'])
    else:
        df['prs'] = 0
    return df

df = df.apply(prs_calculation, axis = 1)

# %%
df
# Out:
#       Product Review ID                  Title  rating  \
# 0                     1            Really Nice     4.0
# 1                     1      Terrific purchase     5.0
# 2                     1         Decent product     3.0
# 3                     1           Nice product     4.0
# 4                     1              Excellent     5.0
# ...                 ...                    ...     ...
# 4890                743     Highly recommended     5.0
# 4891                743           Does the job     3.0
# 4892                743          Great product     5.0
# 4893                743    Best in the market!     5.0
# 4894                743  Mind-blowing purchase     5.0
#
#                                           detail_review  upvote  downvote  \
# 0     The base is becoming a bit Heat within 30 minu...     289        60
# 1     Hey everyone After reading all reviews I have ...     303        71
# 2     Good for Normal useBattery 7/10Display 6/10Mul...      19         1
# 3                  In this price range its best laptop.     109        22
# 4     Very fast laptop go for it little bit heating ...     136        30
# ...                                                 ...     ...       ...
# 4890  This laptop is awesome everything is good the ...       6         1
# 4891  got it for 61k during bbd. performance is quit...       3         0
# 4892                                         Awesome 😎🙌       3         0
# 4893  Don't expect to much from the gaming laptop ba...      12         7
# 4894  Worth for the price, does the job quite wellTh...       4         1
#
#       combinedSentiment sentiment RatingCategory  review_trueness       prs
# 0               0.04175  Positive           Good         0.828080  0.041750
# 1               0.67720  Positive      Excellent         0.810160  0.677200
# 2               0.33785  Positive        Average         0.950000  0.337850
# 3               0.52920  Positive           Good         0.832061  0.529200
# 4               0.52505  Positive      Excellent         0.819277  0.525050
# ...                 ...       ...            ...              ...       ...
# 4890            0.60740  Positive      Excellent         0.857143  0.607400
# 4891            0.35890  Positive        Average         1.000000  0.358900
# 4892            0.62490  Positive      Excellent         1.000000  0.624900
# 4893            0.65325  Positive      Excellent         0.631579  0.412579
# 4894            0.26335  Positive      Excellent         0.800000  0.263350
#
# [4895 rows x 11 columns]

# %%
# result.to_csv('(NLTK)review_sentimental_analysis.csv',index=False)

# %%
df['prs'].sample(10)
# Out:
# 2855    0.000000
# 1523    0.742000
# 2260    0.604400
# 1750   -0.342330
# 3270    0.163932
# 826    -0.075550
# 598     0.000000
# 20      0.498350
# 915     0.210750
# 459     0.454250
# Name: prs, dtype: float64

# %%
df
# Out:
#       Product Review ID                  Title  rating  \
# 0                     1            Really Nice     4.0
# 1                     1      Terrific purchase     5.0
# 2                     1         Decent product     3.0
# 3                     1           Nice product     4.0
# 4                     1              Excellent     5.0
# ...                 ...                    ...     ...
# 4890                743     Highly recommended     5.0
# 4891                743           Does the job     3.0
# 4892                743          Great product     5.0
# 4893                743    Best in the market!     5.0
# 4894                743  Mind-blowing purchase     5.0
#
#                                           detail_review  upvote  downvote  \
# 0     The base is becoming a bit Heat within 30 minu...     289        60
# 1     Hey everyone After reading all reviews I have ...     303        71
# 2     Good for Normal useBattery 7/10Display 6/10Mul...      19         1
# 3                  In this price range its best laptop.     109        22
# 4     Very fast laptop go for it little bit heating ...     136        30
# ...                                                 ...     ...       ...
# 4890  This laptop is awesome everything is good the ...       6         1
# 4891  got it for 61k during bbd. performance is quit...       3         0
# 4892                                         Awesome 😎🙌       3         0
# 4893  Don't expect to much from the gaming laptop ba...      12         7
# 4894  Worth for the price, does the job quite wellTh...       4         1
#
#       combinedSentiment sentiment RatingCategory  review_trueness       prs
# 0               0.04175  Positive           Good         0.828080  0.041750
# 1               0.67720  Positive      Excellent         0.810160  0.677200
# 2               0.33785  Positive        Average         0.950000  0.337850
# 3               0.52920  Positive           Good         0.832061  0.529200
# 4               0.52505  Positive      Excellent         0.819277  0.525050
# ...                 ...       ...            ...              ...       ...
# 4890            0.60740  Positive      Excellent         0.857143  0.607400
# 4891            0.35890  Positive        Average         1.000000  0.358900
# 4892            0.62490  Positive      Excellent         1.000000  0.624900
# 4893            0.65325  Positive      Excellent         0.631579  0.412579
# 4894            0.26335  Positive      Excellent         0.800000  0.263350
#
# [4895 rows x 11 columns]

# %%
df_1 = df[["Product Review ID", "prs"]]
df_1
# Out:
#       Product Review ID       prs
# 0                     1  0.041750
# 1                     1  0.677200
# 2                     1  0.337850
# 3                     1  0.529200
# 4                     1  0.525050
# ...                 ...       ...
# 4890                743  0.607400
# 4891                743  0.358900
# 4892                743  0.624900
# 4893                743  0.412579
# 4894                743  0.263350
#
# [4895 rows x 2 columns]

# %%
avg_scores = df_1.groupby('Product Review ID')['prs'].mean().reset_index()
avg_scores
# Out:
#      Product Review ID       prs
# 0                    1  0.443965
# 1                    2  0.592550
# 2                    3  0.448588
# 3                    4  0.234900
# 4                    6  0.505750
# ..                 ...       ...
# 630                738  0.134110
# 631                739  0.523205
# 632                741  0.496870
# 633                742  0.560777
# 634                743  0.578028
#
# [635 rows x 2 columns]

# %%
# df.to_csv('(NLTK)review_sentimental_analysis.csv',index=False)

# %%
specs_df = pd.read_csv('datasets/flipkart_laptop_specs_data.csv')
specs_df
# Out:
#                                                Product     Price  Rating  \
# 0    HP Intel Celeron Dual Core N4500 - (4 GB/128 G...   21990.0     3.9
# 1    CHUWI Intel Core i3 10th Gen 1005G1 - (8 GB/51...   23990.0     4.1
# 2    APPLE 2022 MacBook Pro Apple M2 - (8 GB/256 GB...  102990.0     4.6
# 3    APPLE 2022 MacBook AIR Apple M2 - (8 GB/512 GB...  119990.0     4.6
# 4    MSI Pulse 17 Intel Core i7 13th Gen 13700H - (...  128990.0     4.9
# ..                                                 ...       ...     ...
# 738  DELL AMD Ryzen 3 Quad Core 5425U - (8 GB/256 G...   38200.0     4.3
# 739  HP Victus AMD Ryzen 5 Hexa Core 5600H - (8 GB/...   54558.0     4.4
# 740  Acer Aspire AMD Ryzen 5 Quad Core 3500U - (8 G...   36999.0     4.3
# 741  HP Omen AMD Ryzen 5 Hexa Core 4600H - (8 GB/51...   59000.0     4.7
# 742  Lenovo IdeaPad Gaming 3 Intel Core i5 12th Gen...   74990.0     4.3
#
#                                            Description  \
# 0    Intel Celeron Dual Core Processor4 GB LPDDR4X ...
# 1    Stylish, Thin and Portable Light Weight Laptop...
# 2    Apple M2 Processor8 GB Unified Memory RAMMac O...
# 3    Apple M2 Processor8 GB Unified Memory RAMMac O...
# 4    Intel Core i7 Processor (13th Gen)16 GB DDR5 R...
# ..                                                 ...
# 738  Processor: R3-5425U (2.70 GHz up to 4.1 GHz)RA...
# 739  AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...
# 740  AMD Ryzen 5 Quad Core Processor8 GB DDR4 RAM64...
# 741  AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...
# 742  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...
#
#                                                    Url  \
# 0    https://www.flipkart.com/hp-intel-celeron-dual...
# 1    https://www.flipkart.com/chuwi-intel-core-i3-1...
# 2    https://www.flipkart.com/apple-2022-macbook-pr...
# 3    https://www.flipkart.com/apple-2022-macbook-ai...
# 4    https://www.flipkart.com/msi-pulse-17-intel-co...
# ..                                                 ...
# 738  https://www.flipkart.com/dell-amd-ryzen-3-quad...
# 739  https://www.flipkart.com/hp-victus-amd-ryzen-5...
# 740  https://www.flipkart.com/acer-aspire-amd-ryzen...
# 741  https://www.flipkart.com/hp-omen-amd-ryzen-5-h...
# 742  https://www.flipkart.com/lenovo-ideapad-gaming...
#
#                                             Review Url  \
# 0    https://www.flipkart.com/hp-intel-celeron-dual...
# 1    https://www.flipkart.com/chuwi-intel-core-i3-1...
# 2    https://www.flipkart.com/apple-2022-macbook-pr...
# 3    https://www.flipkart.com/apple-2022-macbook-ai...
# 4    https://www.flipkart.com/msi-pulse-17-intel-co...
# ..                                                 ...
# 738  https://www.flipkart.com/dell-amd-ryzen-3-quad...
# 739  https://www.flipkart.com/hp-victus-amd-ryzen-5...
# 740  https://www.flipkart.com/acer-aspire-amd-ryzen...
# 741  https://www.flipkart.com/hp-omen-amd-ryzen-5-h...
# 742  https://www.flipkart.com/lenovo-ideapad-gaming...
#
#                                          Sales Package           Model Number  \
# 0           Laptop, battery, power adapter, user guide          15a- na0012TU
# 1                   Laptop, Charger, User Guide Manual        CoreBook X Grey
# 2    MacBook Pro, 67W USB-C Power Adapter, USB-C Ch...              MNEP3HN/A
# 3    MacBook Air, 35W Dual USB-C Port Power Adapter...              MLY23HN/A
# 4    Laptop, battery, power adapter, user guide, La...  Pulse 17 B13VFK-667IN
# ..                                                 ...                    ...
# 738  Laptop, Battery, Adapter, Cables and User Manuals            Vostro 3425
# 739  Laptop, Power Adapter, User Guide, Warranty Do...            15-fb0040AX
# 740  Laptop, Power Adaptor, User Guide, Warranty Do...                A315-23
# 741  Laptop, Power Adaptor, User Guide, Warranty Do...            15-en0002AX
# 742  Laptop, Power Adaptor, User Guide, Warranty Do...                 15IAH7
#
#         Part Number             Model Name  ... Other Accessories  \
# 0       743A1PA#ACJ          15a- na0012TU  ...               NaN
# 1            CWI575             CoreBook X  ...               NaN
# 2         MNEP3HN/A            MacBook Pro  ...               NaN
# 3         MLY23HN/A            MacBook Air  ...               NaN
# 4    9S7-17L531-667  Pulse 17 B13VFK-667IN  ...               NaN
# ..              ...                    ...  ...               ...
# 738   D552305WIN9BE            Vostro 3425  ...               NaN
# 739     6F9T7PA#ACJ            15-fb0040AX  ...               NaN
# 740    NX.HVTSI.008               Aspire 3  ...               NaN
# 741     193D3PA#ACJ                    NaN  ...               NaN
# 742      82S90157IN                 15IAH7  ...               NaN
#
#     HDD Capacity International Warranty Firewire Port Read/Write Speed  \
# 0            NaN                    NaN           NaN              NaN
# 1            NaN                    NaN           NaN              NaN
# 2            NaN                    NaN           NaN              NaN
# 3            NaN                    NaN           NaN              NaN
# 4            NaN                    NaN           NaN              NaN
# ..           ...                    ...           ...              ...
# 738          NaN                    NaN           NaN              NaN
# 739          NaN                    NaN           NaN              NaN
# 740          NaN                    NaN           NaN              NaN
# 741          NaN                    NaN           NaN              NaN
# 742          NaN                    NaN           NaN              NaN
#
#     S-video Color Gamut Cloud Storage Certification Optane Memory
# 0       NaN         NaN           NaN           NaN           NaN
# 1       NaN         NaN           NaN           NaN           NaN
# 2       NaN         NaN           NaN           NaN           NaN
# 3       NaN         NaN           NaN           NaN           NaN
# 4       NaN         NaN           NaN           NaN           NaN
# ..      ...         ...           ...           ...           ...
# 738     NaN         NaN           NaN           NaN           NaN
# 739     NaN         NaN           NaN           NaN           NaN
# 740     NaN         NaN           NaN           NaN           NaN
# 741     NaN         NaN           NaN           NaN           NaN
# 742     NaN         NaN           NaN           NaN           NaN
#
# [743 rows x 101 columns]

# %%
# specs_df['Product ID'] = range(1, len(specs_df) + 1)

# %%
# specs_df

# %%
specs_df.insert(loc=0, column='Product ID', value=range(1, len(specs_df) + 1))

# %%
specs_df
# Out:
#      Product ID                                            Product     Price  \
# 0             1  HP Intel Celeron Dual Core N4500 - (4 GB/128 G...   21990.0
# 1             2  CHUWI Intel Core i3 10th Gen 1005G1 - (8 GB/51...   23990.0
# 2             3  APPLE 2022 MacBook Pro Apple M2 - (8 GB/256 GB...  102990.0
# 3             4  APPLE 2022 MacBook AIR Apple M2 - (8 GB/512 GB...  119990.0
# 4             5  MSI Pulse 17 Intel Core i7 13th Gen 13700H - (...  128990.0
# ..          ...                                                ...       ...
# 738         739  DELL AMD Ryzen 3 Quad Core 5425U - (8 GB/256 G...   38200.0
# 739         740  HP Victus AMD Ryzen 5 Hexa Core 5600H - (8 GB/...   54558.0
# 740         741  Acer Aspire AMD Ryzen 5 Quad Core 3500U - (8 G...   36999.0
# 741         742  HP Omen AMD Ryzen 5 Hexa Core 4600H - (8 GB/51...   59000.0
# 742         743  Lenovo IdeaPad Gaming 3 Intel Core i5 12th Gen...   74990.0
#
#      Rating                                        Description  \
# 0       3.9  Intel Celeron Dual Core Processor4 GB LPDDR4X ...
# 1       4.1  Stylish, Thin and Portable Light Weight Laptop...
# 2       4.6  Apple M2 Processor8 GB Unified Memory RAMMac O...
# 3       4.6  Apple M2 Processor8 GB Unified Memory RAMMac O...
# 4       4.9  Intel Core i7 Processor (13th Gen)16 GB DDR5 R...
# ..      ...                                                ...
# 738     4.3  Processor: R3-5425U (2.70 GHz up to 4.1 GHz)RA...
# 739     4.4  AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...
# 740     4.3  AMD Ryzen 5 Quad Core Processor8 GB DDR4 RAM64...
# 741     4.7  AMD Ryzen 5 Hexa Core Processor8 GB DDR4 RAM64...
# 742     4.3  Intel Core i5 Processor (12th Gen)16 GB DDR4 R...
#
#                                                    Url  \
# 0    https://www.flipkart.com/hp-intel-celeron-dual...
# 1    https://www.flipkart.com/chuwi-intel-core-i3-1...
# 2    https://www.flipkart.com/apple-2022-macbook-pr...
# 3    https://www.flipkart.com/apple-2022-macbook-ai...
# 4    https://www.flipkart.com/msi-pulse-17-intel-co...
# ..                                                 ...
# 738  https://www.flipkart.com/dell-amd-ryzen-3-quad...
# 739  https://www.flipkart.com/hp-victus-amd-ryzen-5...
# 740  https://www.flipkart.com/acer-aspire-amd-ryzen...
# 741  https://www.flipkart.com/hp-omen-amd-ryzen-5-h...
# 742  https://www.flipkart.com/lenovo-ideapad-gaming...
#
#                                             Review Url  \
# 0    https://www.flipkart.com/hp-intel-celeron-dual...
# 1    https://www.flipkart.com/chuwi-intel-core-i3-1...
# 2    https://www.flipkart.com/apple-2022-macbook-pr...
# 3    https://www.flipkart.com/apple-2022-macbook-ai...
# 4    https://www.flipkart.com/msi-pulse-17-intel-co...
# ..                                                 ...
# 738  https://www.flipkart.com/dell-amd-ryzen-3-quad...
# 739  https://www.flipkart.com/hp-victus-amd-ryzen-5...
# 740  https://www.flipkart.com/acer-aspire-amd-ryzen...
# 741  https://www.flipkart.com/hp-omen-amd-ryzen-5-h...
# 742  https://www.flipkart.com/lenovo-ideapad-gaming...
#
#                                          Sales Package           Model Number  \
# 0           Laptop, battery, power adapter, user guide          15a- na0012TU
# 1                   Laptop, Charger, User Guide Manual        CoreBook X Grey
# 2    MacBook Pro, 67W USB-C Power Adapter, USB-C Ch...              MNEP3HN/A
# 3    MacBook Air, 35W Dual USB-C Port Power Adapter...              MLY23HN/A
# 4    Laptop, battery, power adapter, user guide, La...  Pulse 17 B13VFK-667IN
# ..                                                 ...                    ...
# 738  Laptop, Battery, Adapter, Cables and User Manuals            Vostro 3425
# 739  Laptop, Power Adapter, User Guide, Warranty Do...            15-fb0040AX
# 740  Laptop, Power Adaptor, User Guide, Warranty Do...                A315-23
# 741  Laptop, Power Adaptor, User Guide, Warranty Do...            15-en0002AX
# 742  Laptop, Power Adaptor, User Guide, Warranty Do...                 15IAH7
#
#         Part Number  ... Other Accessories HDD Capacity  \
# 0       743A1PA#ACJ  ...               NaN          NaN
# 1            CWI575  ...               NaN          NaN
# 2         MNEP3HN/A  ...               NaN          NaN
# 3         MLY23HN/A  ...               NaN          NaN
# 4    9S7-17L531-667  ...               NaN          NaN
# ..              ...  ...               ...          ...
# 738   D552305WIN9BE  ...               NaN          NaN
# 739     6F9T7PA#ACJ  ...               NaN          NaN
# 740    NX.HVTSI.008  ...               NaN          NaN
# 741     193D3PA#ACJ  ...               NaN          NaN
# 742      82S90157IN  ...               NaN          NaN
#
#     International Warranty Firewire Port Read/Write Speed S-video Color Gamut  \
# 0                      NaN           NaN              NaN     NaN         NaN
# 1                      NaN           NaN              NaN     NaN         NaN
# 2                      NaN           NaN              NaN     NaN         NaN
# 3                      NaN           NaN              NaN     NaN         NaN
# 4                      NaN           NaN              NaN     NaN         NaN
# ..                     ...           ...              ...     ...         ...
# 738                    NaN           NaN              NaN     NaN         NaN
# 739                    NaN           NaN              NaN     NaN         NaN
# 740                    NaN           NaN              NaN     NaN         NaN
# 741                    NaN           NaN              NaN     NaN         NaN
# 742                    NaN           NaN              NaN     NaN         NaN
#
#     Cloud Storage Certification Optane Memory
# 0             NaN           NaN           NaN
# 1             NaN           NaN           NaN
# 2             NaN           NaN           NaN
# 3             NaN           NaN           NaN
# 4             NaN           NaN           NaN
# ..            ...           ...           ...
# 738           NaN           NaN           NaN
# 739           NaN           NaN           NaN
# 740           NaN           NaN           NaN
# 741           NaN           NaN           NaN
# 742           NaN           NaN           NaN
#
# [743 rows x 102 columns]

# %%
new_df = specs_df.join(avg_scores.set_index('Product Review ID'), on='Product ID')

# %%
new_df['prs']
# Out:
# 0      0.443965
# 1      0.592550
# 2      0.448588
# 3      0.234900
# 4           NaN
#          ...
# 738    0.523205
# 739         NaN
# 740    0.496870
# 741    0.560777
# 742    0.578028
# Name: prs, Length: 743, dtype: float64

# %%
new_df.to_csv('datasets/Recommendation_PRS_specs_data.csv',index=False)
